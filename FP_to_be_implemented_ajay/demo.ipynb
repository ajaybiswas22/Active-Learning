# %%
### to be implemented

# %%
from resources.basicIO import InputOutput as IO
from resources.filterLang import FilterLanguage as FL
from resources.tokTT import CommentTokenizer as CT

# %%
freq = CT.get_word_frequency('datasets/corpus.txt')
print(freq)
# Out:
# {'is': 9789, 'to': 9630, 'and': 9168, 'of': 8279, 'in': 6072, 'farmers': 5655, 'are': 5063, 'not': 4722, 'for': 4521, 'this': 4412, 'they': 3527, 'you': 3344, 'it': 3122, 'will': 2907, 'that': 2709, 'i': 2685, 'on': 2602, 'be': 2533, 'india': 2410, 'have': 2210, 'all': 2146, 'with': 2000, 'by': 1945, 'people': 1896, 'do': 1838, 'but': 1796, 'we': 1686, 'these': 1685, 'so': 1663, 'from': 1638, 'he': 1602, 'their': 1588, 'bjp': 1581, 'modi': 1552, 'no': 1549, 'as': 1533, 'government': 1524, 'who': 1521, 'what': 1464, 'if': 1404, 'should': 1368, 'can': 1320, 'why': 1268, 'only': 1261, 'them': 1215, 'or': 1200, 'has': 1182, 'now': 1171, 'farmer': 1140, 'govt': 1113, 'was': 1089, 'like': 1062, 'laws': 1005, 'good': 999, 'your': 998, 'our': 997, 'country': 987, 'there': 982, 'one': 974, 'at': 968, 'indian': 968, 'very': 951, 'hai': 923, 'protest': 918, 'sir': 904, 'about': 878, 'more': 853, 'just': 850, 'how': 837, 'up': 822, 'farm': 811, 'police': 771, 'any': 758, 'media': 753, 'support':
# ...
