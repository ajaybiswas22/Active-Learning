# %%
"""
@Author Ajay Biswas
"""

from http.client import responses
import os
import googleapiclient.discovery
from lib.keys import api_key as DEVELOPER_KEY
import numpy as np
import pandas as pd
import json
import csv

# %%
# API CALL
api_service_name = "youtube"
api_version = "v3"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet,replies",
    #maxResults=100,
    videoId="oQlicIzQork"
)
response = request.execute()
#print(response)

# %%
comments_total = len(response['items'])

# save comments to csv
fields = ['Username', 'Comment'] 

# lists
user_name = []
user_comment = []

for i in range(comments_total):
    user_comment.append(response['items'][i]['snippet']['topLevelComment']['snippet']['textOriginal'])
    user_name.append(response['items'][i]['snippet']['topLevelComment']['snippet']['authorDisplayName'])
    
rows = [user_name,user_comment]

# save into csv
pd.DataFrame({'Username': user_name, 'Comment': user_comment}).to_csv('dataset/video1.csv', index=False)

# %%
# display the dataset
output = pd.read_csv("dataset/video1.csv")
display(output)
# Out:
#               Username                                            Comment
# 0   Study IQ education  Click here to buy full UPSC course https://pla...
# 1          nadeem baig                                   Good job...sir..
# 2        Anupam Pandey  इसमें काफी बातें अवधारणा से प्रेरित हैं। एक अध...
# 3      Sagar Raj Nayak                                      Thank you Sir
# 4       Gurpreet Singh                                     Excellent sir👍
# 5     gaganpreet singh                                       Well-done ji
# 6        mukesh sharma  Conclusion is..m.s.p should be compulsory for ...
# 7         sushma singh  खान सर आपको बहुत-बहुत धन्यवाद। मैं किसान नहीं ...
# 8       Shreya Khusboo                                            Best 🙏👍
# 9       Aditya Rana 7b                        Good understanding video 👍👍
# 10        Rita Gunhere                                         Awwwwwsome
# 11    Prashant Devarde  Govt should have control on both APMc and priv...
# 12         Safdar Gazi          Good explanation.......... Clear crystal🔮
# 13    neha singh singh                      Govt should interfere in MSP.
# 14    Sadanand Gawande             It's aTransparent information .. Good👍
# 15          NAJOOMI JI  कृषि कानून से संबंधित सिर्फ़ पांच प्रश्न :\n\n1...
# 16  Niharika Choudhary                                    Very good video
# 17           Altiya .h  Private sector are those institutions who burn...
# 18     Prajakta Ganvir                                   Mahipal atta 🤣🤣🤣
# 19               Vidhi  the farmers bill (2020) is like getting protei...
