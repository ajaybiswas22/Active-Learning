# %%
import os
import googleapiclient.discovery
from lib.keys import api_key as DEVELOPER_KEY
import numpy as np
import pandas as pd
import json
import csv

# API CALL
api_service_name = "youtube"
api_version = "v3"


youtube = googleapiclient.discovery.build(
api_service_name, api_version, developerKey = DEVELOPER_KEY)


request = youtube.search().list(
    part="snippet",
    maxResults=50,
    q="farmer protest"
)
response = request.execute()

#print(response)

# %%
videos_total = len(response['items'])

# save comments to csv

# lists
video_Id = []
video_Title = []
channel_Id = []
channel_name = []
video_Date = []

for i in range(videos_total):
    video_Id.append(response['items'][i]['id']['videoId'])
    video_Title.append(response['items'][i]['snippet']['title'])
    channel_Id.append(response['items'][i]['snippet']['channelId'])
    channel_name.append(response['items'][i]['snippet']['channelTitle'])
    video_Date.append(response['items'][i]['snippet']['publishedAt'])

# save into csv
pd.DataFrame({'videoId': video_Id, 
              'title': video_Title, 
              'channelId': channel_Id,
              'channelName': channel_name,
              'date': video_Date}).to_csv('dataset/searchResults.csv', index=False)

# %%
# display the dataset
output = pd.read_csv("dataset/searchResults.csv")
display(output)
# Out:
#         videoId                                              title  \
# 0   i73m2F-Gvj4  Farmer Protest: Singhu Border पर प्रदर्शन कर र...
# 1   IaEqq3rDinA  क्या Farmer Protest खत्म हो जाने से Corona महा...
# 2   l6JhNVJaC_Q  Farmers Protest: किसान आंदोलन को 6 महीने पूरे,...
# 3   yVa2yOZTl2o  🔴 LIVE Kisan Morcha Delhi | 26 May 2021  |Farm...
# 4   KJg7jHF160I  Corona के बीच फिर से तेज हुआ Farmers Protest, ...
# 5   TZMykdF91c4  Farmers Protest: Amid Covid Curbs, Haryana And...
# 6   AW5EQc3Y5F0  3,000 Riot Cops Called Into Haryana&#39;s Hisa...
# 7   PCIZ98VCynE  Rakesh Tikait Speaks On Farmer&#39;s &#39;Blac...
# 8   RFI5aHBE6Kk  കർഷകരുടെ സമരഭൂമിയിൽ ഇന്ന് കരിദിനം| Farmers&#39...
# 9   brK7d9JBFfo  Farmers Protest in the age of COVID | Who is r...
# 10  meEKrHKPdwk  🔴 LIVE Kisan Morcha Delhi | 26 May 2021  |Farm...
# 11  Rk5tbtuWqfM  राकेश टिकैत के बोलते ही बॉर्डर पर ये हैं हालात...
# 12  _NvdezBMwsk  Farmer Protest: कृषि कानून पर बोले Rakesh Tika...
# 13  V2TGI6Q1yq0  Farmer Protest Turned Villages Into Covid Hots...
# 14  5AC00KN-1cE  Farmers Protest: Punjab Farmers Head To Delhi ...
# 15  jWEbr_qmQLM  ਕਾਲੇ ਦਿਨ ਦੇ ਰੋਸ Farmers Protest |Singhu Kundal...
# 16  wOiQ0XZSRlE  Watch: Amid Covid, farmers march to Delhi; pro...
# 17  aZmwz-YBL1k  Two Farmer Unions Withdraw Protest, Condemn Re...
# 18  jpYr6o_GCZ4  പ്രധാനമന്ത്രിയുടെ കോലം കത്തിച്ച് കർഷകരുടെ പ്രത...
# 19  iHpZV7ro7lU        India&#39;s huge farmer protests, explained
# 20  W2VM330HCLs  Farmers Protest: 6 Months Of Farmers&#39; Prot...
# 21  RCULnH633yQ  Farmer leader Balbir Singh Rajewal: ‘If we get...
# 22  wSPpT_EBh6o  Farmers Protest: आंदोलन के 6 महीने पूरे, किसान...
# 23  ggUYFQNFGDY  Farmer Protest : ‘Kisan तांडव’ की New Date 26 ...
# 24  LtPorBcfMrc  &#39;Beware Of BJP&#39;: Rakesh Tikait Takes F...
# 25  4_UDPhJ6GKs  Farmer Protest || ਕਿਸਾਨਾਂ ਨੇ ਕ੍ਰੇਨ &#39;ਤੇ ਟੰਗ...
# 26  od3Y5XNdyMc  6 months of Farmers protest: 26 may के लिए किस...
# 27  EooHHGLXBxY  Coronavirus Crisis In India: Farmers Protest S...
# 28  -I3IhX3gnPg  Protesting Farmers March With Black Flags To M...
# 29  _g9gSrpnq5g  Kisan Bandh Call | 6 Months Of Farmers Protest...
# 30  _W5UfJQDv2Q  Farmer Black Day | Farmers&#39; Protest Comple...
# 31  0og0etHQXHQ  Haryana Farmers Protest: Hisra में बोले Rakesh...
# 32  0Nw2gjTN3uc  Corona की Second Wave के बीच तेज हुआ Farmer Pr...
# 33  LjS6TcZu94E  Farmers&#39; protests in India intensify | DW ...
# 34  fIXJQt6jB84  Superspreader Farmer Protests are Back | Kisan...
# 35  F-jGAAtHUPE  Kisan Andolan Live Update: कोरोना काल में ‘Bla...
# 36  GUzjqSiaMhs  Farmers mark 6 months of stir with &#39;Black ...
# 37  3nskU3BoGtc  Farmers protest: Indian farmers clash with pol...
# 38  CPVxSGUllrk  Farmers Protest: 26 May को किसान संगठनों द्वार...
# 39  BYA2049gCq4  How the world has reacted to farmer protests i...
# 40  Jo4rAd3BWeg  Farmer Song : The Folkman Latest Punjabi Songs...
# 41  ozfXDXWPXn8  100 days &amp; counting, farmers protest is no...
# 42  iAjATdoi5PI  Farmers Continue To Protest At Singhu Border A...
# 43  UjIDN5JX-sY  India farmers protests: &#39;Delhi highways ar...
# 44  hbGzyo51anU  Farmers Protest | Modified Tractor Worth Rs 40...
# 45  iRrruZPUAMY  किसान आंदोलन के 6 महीने पुरे|मोदी का पुतला जला...
# 46  EtYzkXJn894  Breaking News: 26 मई को किसान करेंगे देशव्यापी...
# 47  DE4MgKQtuyY  Farmers&#39; Protest Amid Covid: Hundreds Of F...
# 48  _hKwY9Sxo_s              Clashes Erupt at India Farmer Protest
# 49  aoz9lLlD9dM  Farmers Protest in Delhi | Farm Bills 2020 Exp...
#
#                    channelId                     channelName  \
# 0   UCN7B-QD0Qgn2boVH5Q0pOWg                  BBC News Hindi
# 1   UCuzS3rPQAYqHcLWqOFuY0pw                          News24
# 2   UCSKgOW8Pg_eZymYJyJc432g     Dainik Jagran - दैनिक जागरण
# 3   UC5PhyMixgPl-KGCJ0VLdXxw               Sangat Television
# 4   UCx8Z14PpntdaxCt2hakbQLQ                   The Lallantop
# 5   UCZFMm1mMw0F81Z37aaEzTUA                            NDTV
# 6   UCZFMm1mMw0F81Z37aaEzTUA                            NDTV
# 7   UCwqusr8YDwM-3mEYTDeJHzw                  Republic World
# 8   UCf8w5m0YsRa8MHQ5bwSGmbw                     asianetnews
# 9   UCrdPiSPVW0rtRsI002BX8iw                      MOJO STORY
# 10  UC5PhyMixgPl-KGCJ0VLdXxw               Sangat Television
# 11  UCDHaADxnyz9_DKY_zsmuw4w                       NEWS MATE
# 12  UCt4t-jeY85JegMlZ-E5UWtA                         Aaj Tak
# 13  UCYPvAwZP8pZhSMW8qs7cVCw                     India Today
# 14  UCZFMm1mMw0F81Z37aaEzTUA                            NDTV
# 15  UC5PhyMixgPl-KGCJ0VLdXxw               Sangat Television
# 16  UCm7lHFkt2yB_WzL67aruVBQ                 Hindustan Times
# 17  UCwqusr8YDwM-3mEYTDeJHzw                  Republic World
# 18  UCf8w5m0YsRa8MHQ5bwSGmbw                     asianetnews
# 19  UCLXo7UDZvByw2ixzpQCufnA                             Vox
# 20  UCZFMm1mMw0F81Z37aaEzTUA                            NDTV
# 21  UCustbySVJGb659WDpdkeATg                     newslaundry
# 22  UC9CYT9gSNLevX5ey2_6CK0Q                      NDTV India
# 23  UCjFKMoAk3qhRkW4eOqNm6dw                   Zee Hindustan
# 24  UCYPvAwZP8pZhSMW8qs7cVCw                     India Today
#