# %%
import os
import googleapiclient.discovery
from lib.keys import api_key as DEVELOPER_KEY
import numpy as np
import pandas as pd
import json
import csv

# API CALL
api_service_name = "youtube"
api_version = "v3"


youtube = googleapiclient.discovery.build(
api_service_name, api_version, developerKey = DEVELOPER_KEY)


request = youtube.search().list(
    part="snippet",
    maxResults=50,
    q="farmer protest"
)
response = request.execute()

#print(response)

# %%
videos_total = len(response['items'])

# save comments to csv

# lists
video_Id = []
video_Title = []
channel_Id = []
channel_name = []
video_Date = []

for i in range(videos_total):
    video_Id.append(response['items'][i]['id']['videoId'])
    video_Title.append(response['items'][i]['snippet']['title'])
    channel_Id.append(response['items'][i]['snippet']['channelId'])
    channel_name.append(response['items'][i]['snippet']['channelTitle'])
    video_Date.append(response['items'][i]['snippet']['publishedAt'])

# save into csv
pd.DataFrame({'videoId': video_Id, 
              'title': video_Title, 
              'channelId': channel_Id,
              'channelName': channel_name,
              'date': video_Date}).to_csv('dataset/searchResults.csv', index=False)

# %%
# display the dataset
output = pd.read_csv("dataset/searchResults.csv")
display(output)
# Out:
#         videoId                                              title  \
# 0   qZoK_fF4SOg  Farmer Protest: किस मोड़ पर है किसान आंदोलन और...
# 1   W2VM330HCLs  Farmers Protest: 6 Months Of Farmers&#39; Prot...
# 2   a5Sv1sK3ia4  India farmers burn effigies of Modi to mark 6 ...
# 3   PCIZ98VCynE  Rakesh Tikait Speaks On Farmer&#39;s &#39;Blac...
# 4   CckwXQHILb0  Farm laws के खिलाफ Farmers protest के six mont...
# 5   AW5EQc3Y5F0  3,000 Riot Cops Called Into Haryana&#39;s Hisa...
# 6   uigsiLSxpLk  Taal Thok Ke LIVE: आंदोलनजीवी या &#39;Corona&#...
# 7   YySPbt_CdGI  Des Ki Baat: 6 Months Of Farmers&#39; Protest:...
# 8   _g9gSrpnq5g  Kisan Bandh Call | 6 Months Of Farmers Protest...
# 9   i73m2F-Gvj4  Farmer Protest: Singhu Border पर प्रदर्शन कर र...
# 10  5AC00KN-1cE  Farmers Protest: Punjab Farmers Head To Delhi ...
# 11  V2TGI6Q1yq0  Farmer Protest Turned Villages Into Covid Hots...
# 12  aZmwz-YBL1k  Two Farmer Unions Withdraw Protest, Condemn Re...
# 13  IaEqq3rDinA  क्या Farmer Protest खत्म हो जाने से Corona महा...
# 14  wOiQ0XZSRlE  Watch: Amid Covid, farmers march to Delhi; pro...
# 15  TPn028g4Jbw  After 6 months, farmers protest gets intense |...
# 16  TZMykdF91c4  Farmers Protest: Amid Covid Curbs, Haryana And...
# 17  iKVVBEhTS_4  Kumar Vishwas ने Saurabh Dwivedi से Corona मदद...
# 18  _NvdezBMwsk  Farmer Protest: कृषि कानून पर बोले Rakesh Tika...
# 19  iHpZV7ro7lU        India&#39;s huge farmer protests, explained
# 20  brK7d9JBFfo  Farmers Protest in the age of COVID | Who is r...
# 21  KI-GcjOajek  🔴 LIVE Kisan Morcha Delhi | 27 May 2021  |Farm...
# 22  F-jGAAtHUPE  Kisan Andolan Live Update: कोरोना काल में ‘Bla...
# 23  0Nw2gjTN3uc  Corona की Second Wave के बीच तेज हुआ Farmer Pr...
# 24  LtPorBcfMrc  &#39;Beware Of BJP&#39;: Rakesh Tikait Takes F...
# 25  KJg7jHF160I  Corona के बीच फिर से तेज हुआ Farmers Protest, ...
# 26  RCULnH633yQ  Farmer leader Balbir Singh Rajewal: ‘If we get...
# 27  od3Y5XNdyMc  6 months of Farmers protest: 26 may के लिए किस...
# 28  LjS6TcZu94E  Farmers&#39; protests in India intensify | DW ...
# 29  XhsGSItpxO0  ਲੱਖਾ ਸਿਧਾਣਾ ਨੇ ਦਿੱਤਾ ਚਕਮਾ Lakha Sidhana reache...
# 30  3nskU3BoGtc  Farmers protest: Indian farmers clash with pol...
# 31  7tmVejgaIYE  Protest Until Farm Laws Are Scrapped: Farmer L...
# 32  yVa2yOZTl2o  🔴 LIVE Kisan Morcha Delhi | 26 May 2021  |Farm...
# 33  BYA2049gCq4  How the world has reacted to farmer protests i...
# 34  EooHHGLXBxY  Coronavirus Crisis In India: Farmers Protest S...
# 35  hZMjkLgHTCc  Farmers Protest: Hisar में प्रदर्शन, किसान यून...
# 36  l6JhNVJaC_Q  Farmers Protest: किसान आंदोलन को 6 महीने पूरे,...
# 37  4_UDPhJ6GKs  Farmer Protest || ਕਿਸਾਨਾਂ ਨੇ ਕ੍ਰੇਨ &#39;ਤੇ ਟੰਗ...
# 38  hbGzyo51anU  Farmers Protest | Modified Tractor Worth Rs 40...
# 39  DE4MgKQtuyY  Farmers&#39; Protest Amid Covid: Hundreds Of F...
# 40  UjIDN5JX-sY  India farmers protests: &#39;Delhi highways ar...
# 41  rh4DExjppeo  Farmers Protest को 6 महीने पूरे: किसानों ने फू...
# 42  G6T6cM_DFyU  Delhi Chalo Campaign by Farmers - Why farmers ...
# 43  g_TmFrcmG2g  Farmers Protest: Rakesh Tikait&#39;s Tears Bec...
# 44  ozfXDXWPXn8  100 days &amp; counting, farmers protest is no...
# 45  iAjATdoi5PI  Farmers Continue To Protest At Singhu Border A...
# 46  Kk0krThJWgI  Balbir Singh Rajewal Today Speech Delhi singhu...
# 47  _hKwY9Sxo_s              Clashes Erupt at India Farmer Protest
# 48  _W5UfJQDv2Q  Farmer Black Day | Farmers&#39; Protest Comple...
# 49  yOH7BDvOzxY  Bella Ciao - Punjabi | Farm Laws Wapas Jao | #...
#
#                    channelId                     channelName  \
# 0   UCN7B-QD0Qgn2boVH5Q0pOWg                  BBC News Hindi
# 1   UCZFMm1mMw0F81Z37aaEzTUA                            NDTV
# 2   UChLtXXpo4Ge1ReTEboVvTDg                     Global News
# 3   UCwqusr8YDwM-3mEYTDeJHzw                  Republic World
# 4   UCx8Z14PpntdaxCt2hakbQLQ                   The Lallantop
# 5   UCZFMm1mMw0F81Z37aaEzTUA                            NDTV
# 6   UCIvaYmXn910QMdemBG3v1pQ                        Zee News
# 7   UCZFMm1mMw0F81Z37aaEzTUA                            NDTV
# 8   UCYPvAwZP8pZhSMW8qs7cVCw                     India Today
# 9   UCN7B-QD0Qgn2boVH5Q0pOWg                  BBC News Hindi
# 10  UCZFMm1mMw0F81Z37aaEzTUA                            NDTV
# 11  UCYPvAwZP8pZhSMW8qs7cVCw                     India Today
# 12  UCwqusr8YDwM-3mEYTDeJHzw                  Republic World
# 13  UCuzS3rPQAYqHcLWqOFuY0pw                          News24
# 14  UCm7lHFkt2yB_WzL67aruVBQ                 Hindustan Times
# 15  UCRWFSbif-RFENbBrSiez1DA                        ABP NEWS
# 16  UCZFMm1mMw0F81Z37aaEzTUA                            NDTV
# 17  UCx8Z14PpntdaxCt2hakbQLQ                   The Lallantop
# 18  UCt4t-jeY85JegMlZ-E5UWtA                         Aaj Tak
# 19  UCLXo7UDZvByw2ixzpQCufnA                             Vox
# 20  UCrdPiSPVW0rtRsI002BX8iw                      MOJO STORY
# 21  UC5PhyMixgPl-KGCJ0VLdXxw               Sangat Television
# 22  UCjFKMoAk3qhRkW4eOqNm6dw                   Zee Hindustan
# 23  UCOutOIcn_oho8pyVN3Ng-Pg                 TV9 Bharatvarsh
# 24  UCYPvAwZP8pZhSMW8qs7cVCw                     India Today
# 25  UCx8Z14PpntdaxCt2hakbQLQ                   The Lallantop
#