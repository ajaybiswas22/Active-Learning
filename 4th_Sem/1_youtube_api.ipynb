# %% [markdown]
# # Dataset YouTube API

# %%
import googleapiclient.discovery
from resources.keys import api_key as DEVELOPER_KEY
import pandas as pd
from resources.basicIO import InputOutput as IO

# %% [markdown]
# ## API Call

# %%
# API CALL
api_service_name = "youtube"
api_version = "v3"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# %% [markdown]
# ## Fetch Channels from YouTube

# %%
queries = ["lakhimpur violence", "farmer protest","kisan andolan","farmer bill", 
           "agriculture reform bill 2020","kisan morcha","rakesh tikait",
           "kisan mahapanchayat","farmers march","Farmer Protest LatestNews",
           "Doubling farmers income","krishi mandi","farmlaws","Krishi Bill 2020",
           "Haryana farmers Protest","farmer protest delhi border","A Day at the Tikri Border",
           "farmers protest in Tohana","tractor rally delhi","kisan vs police","kisan riot",
           "kisan taliban","farmers bill withdrawn"]
    

# lists
video_Id = []
video_Title = []
channel_Id = []
channel_name = []
video_Date = []

# take multiple search results
for i in range(len(queries)):
    request = youtube.search().list(
        part="snippet",
        maxResults=50,
        q=queries[i]
    )
    response = request.execute()
    videos_total = len(response['items'])

    # all parsed videos
    for i in range(videos_total):
        # insert if unique video id

        try:
            if response['items'][i]['id']['videoId'] not in video_Id:
                video_Id.append(response['items'][i]['id']['videoId'])
                video_Title.append(response['items'][i]['snippet']['title'])
                channel_Id.append(response['items'][i]['snippet']['channelId'])
                channel_name.append(
                    response['items'][i]['snippet']['channelTitle'])
                video_Date.append(
                    response['items'][i]['snippet']['publishedAt'])
        except:
            print('VideoId miss')
# Out:
# VideoId miss
# VideoId miss
# VideoId miss

# %% [markdown]
# ### Make a csv Database for search results

# %%
pd.DataFrame({'videoId': video_Id,
              'title': video_Title,
              'channelId': channel_Id,
              'channelName': channel_name,
              'date': video_Date}).to_csv('datasets/search_results.csv', index=False)

# %%
# display the dataset
output = pd.read_csv("datasets/search_results.csv")
display(output)
# Out:
#          videoId                                              title  \
# 0    l1oobMY7CE4  Lakhimpur Kheri Violence - 8 people killed, Ca...
# 1    v_xiGjSd6aw  Watch: Full 1 minute 45 second Video of Lakhim...
# 2    XcMqzv3KWNA  Lakhimpur Kheri Violence: Video Of Questioning...
# 3    Gz7kaVLbvJY  DNA: लखीमपुर खीरी हिंसा में हुई मौतों का जिम्म...
# 4    K4dt_3O5Tr4  Lakhimpur Violence : किसान के बेटे ने बताया, क...
# ..           ...                                                ...
# 966  Si2jd58t9so  Rahul Gandhi to Amarinder Singh: How netas rea...
# 967  euIRCvyzXAY  Farm Bills Debate: Politics, Protests &amp; Pa...
# 968  mOju1aLURQ4  PM Modi addresses the Nation | Withdraws 3 far...
# 969  9-jC5o4w1gk  Protesting Farmers in Singhu Border Celebrate ...
# 970  zpjs_XNESq0  Union Cabinet PASSES PROPOSAL to withdraw Farm...
#
#                     channelId          channelName                  date
# 0    UCrC8mOqJQpoB7NuIMKIS6rQ   Study IQ education  2021-10-04T05:45:19Z
# 1    UCwqusr8YDwM-3mEYTDeJHzw       Republic World  2021-10-05T09:05:09Z
# 2    UCZFMm1mMw0F81Z37aaEzTUA                 NDTV  2021-10-06T05:52:52Z
# 3    UCIvaYmXn910QMdemBG3v1pQ             Zee News  2021-10-04T16:31:47Z
# 4    UCx8Z14PpntdaxCt2hakbQLQ        The Lallantop  2021-10-04T07:18:24Z
# ..                        ...                  ...                   ...
# 966  UCm7lHFkt2yB_WzL67aruVBQ      Hindustan Times  2021-11-19T08:45:00Z
# 967  UCYPvAwZP8pZhSMW8qs7cVCw          India Today  2020-09-21T15:29:27Z
# 968  UC6RJ7-PaXg6TIH2BzZfTV7w            TIMES NOW  2021-11-19T04:31:03Z
# 969  UCJEDFSxHHOW1PpBccdSxOTA  IndianExpressOnline  2021-11-19T06:52:38Z
# 970  UCRWFSbif-RFENbBrSiez1DA             ABP NEWS  2021-11-24T08:19:40Z
#
# [971 rows x 5 columns]

# %% [markdown]
# ## Fetch Comments from YouTube

# %%
search_results = pd.read_csv("datasets/search_results.csv")

# lists
user_name = []
user_comment = []
user_likes_count = []
video_id = []

for i in range(len(search_results)):
    try:
        videoID = (search_results['videoId'][i])

        request = youtube.commentThreads().list(
        part="snippet,replies",
        maxResults=100,
        videoId=videoID)
        response = request.execute()

        comments_total = len(response['items'])

        for j in range(comments_total):
            video_id.append(videoID)
            user_comment.append(response['items'][j]['snippet']['topLevelComment']['snippet']['textOriginal'])
            user_name.append(response['items'][j]['snippet']['topLevelComment']['snippet']['authorDisplayName'])
            user_likes_count.append(response['items'][j]['snippet']['topLevelComment']['snippet']['likeCount'])
    except:
        #print('Comment disabled for ',search_results['videoId'][i])
        pass

# %% [markdown]
# ### Make a csv for comments

# %%
# save into csv
pd.DataFrame({'Username': user_name, 'Comment': user_comment, 'Likes': user_likes_count,
             'Video ID': video_id}).to_csv('datasets/comments.csv', index=False)

# %%
# display the dataset
output = pd.read_csv("datasets/comments.csv")
display(output)
# Out:
#                   Username                                            Comment  \
# 0       Study IQ education  Click here to buy full UPSC course https://pla...
# 1      satya prakash yadav          Jay mere desh ke kishan. You is real god.
# 2           Nobhonil Gupta  LOL, I m From Assam, after Watching Lakhimpur,...
# 3                     Sneh                                                  C
# 4                    AKASH       Video evidence of his son is still not out..
# ...                    ...                                                ...
# 53798          Harp Dhanda                                           We won ✊
# 53799          praful pote                   आज समझ आया कैबिनेट का\nमहत्व है।
# 53800          Mohd. Talib            Abani bola modi budha ho gaya hai .....
# 53801          Ather mirza                            Inko sab kuch pata hota
# 53802        Pradeep Yadav  ABP walo ko pata rahta hain kab kya hone wala ...
#
#        Likes     Video ID
# 0         37  l1oobMY7CE4
# 1         45  l1oobMY7CE4
# 2         23  l1oobMY7CE4
# 3          0  l1oobMY7CE4
# 4          5  l1oobMY7CE4
# ...      ...          ...
# 53798      1  zpjs_XNESq0
# 53799      0  zpjs_XNESq0
# 53800      0  zpjs_XNESq0
# 53801      0  zpjs_XNESq0
# 53802      2  zpjs_XNESq0
#
# [53803 rows x 4 columns]

# %% [markdown]
# ### Save comments in a text file

# %%
corpus = list(set(user_comment))
IO.save_text('datasets/comments.txt',corpus)
